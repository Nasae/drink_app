# %%
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./../en.openfoodfacts.org.products.csv", low_memory=False, encoding='utf-8', sep='\t')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1705429 entries, 0 to 1705428
# Columns: 184 entries, code to carnitine_100g
# dtypes: float64(123), int64(2), object(59)
# memory usage: 2.3+ GB

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
reduce_mem_usage(data)
# Out:
# Mem. usage decreased to 1307.64 Mb (45.4% reduction)
#                          code  \
# 0               0000000000017
# 1               0000000000031
# 2          000000000003327986
# 3               0000000000100
# 4        00000000001111111111
# ...                       ...
# 1705424         9999999910128
# 1705425             999999999
# 1705426         9999999990397
# 1705427         9999999999994
# 1705428       999999999999999
#
#                                                        url  \
# 0        http://world-en.openfoodfacts.org/product/0000...
# 1        http://world-en.openfoodfacts.org/product/0000...
# 2        http://world-en.openfoodfacts.org/product/0000...
# 3        http://world-en.openfoodfacts.org/product/0000...
# 4        http://world-en.openfoodfacts.org/product/0000...
# ...                                                    ...
# 1705424  http://world-en.openfoodfacts.org/product/9999...
# 1705425  http://world-en.openfoodfacts.org/product/9999...
# ...

# %%
data_new = data.copy()

# %%
del(data)

# %%
cols = data_new.columns.str.contains('_100g|origins|categories|nutriscore_score|nutriscore_grade|product_name')
data_new = data_new.loc[:, cols]

# %%
cols_del = data_new.columns.str.contains('abbreviated|_tags|_en')
data_new = data_new.drop(data_new.loc[:, cols_del].columns, axis = 1)

# %%
data_new.to_csv('./../en.openfoodfacts.org.products.cleaned.csv', index=False)

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1705429 entries, 0 to 1705428
# Columns: 116 entries, product_name to carnitine_100g
# dtypes: float16(100), float32(8), float64(4), object(4)
# memory usage: 481.4+ MB

# %%
data_new.dtypes
# Out:
# product_name           object
# categories             object
# origins                object
# nutriscore_score      float16
# nutriscore_grade       object
#                        ...
# choline_100g          float16
# phylloquinone_100g    float16
# beta-glucan_100g      float16
# inositol_100g         float16
# carnitine_100g        float16
# Length: 116, dtype: object

# %%
for col in data_new.select_dtypes(exclude = 'object'):
    plt.figure()
    sns.distplot(data_new[col])
# Out:
# /home/anasse/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/anasse/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for col in data_new.select_dtypes('object'):
    print(f'{col :-<50} {data_new[col].nunique()}')
# Out:
# product_name-------------------------------------- 1075304
# categories---------------------------------------- 102027
# origins------------------------------------------- 12228
# nutriscore_grade---------------------------------- 5
